# %% [markdown]
# # [YOLOv8](https://docs.ultralytics.com/)
#
# ## 설치
#
# - `pip install ultralytics`
# - 주피터노트북에서 실행할 경우 프로그래스바를 실행하기 위해서 다음을 설치한다. (필수는 아님)
#     - `pip install ipywidgets` or `conda install -y -c conda-forge ipywidgets`

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/12/44/1ae54087337a2a446fd3a2876570765a3c2676e481f7bf8cc81a45ded356/ultralytics-8.0.207-py3-none-any.whl.metadata
#   Downloading ultralytics-8.0.207-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: numpy>=1.22.2 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (1.26.0)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/05/58/7ee92b21cb98689cbe28c69e3cf8ee51f261bfb6bc904ae578736d22d2e7/opencv_python-4.8.1.78-cp37-abi3-macosx_10_16_x86_64.whl.metadata
#   Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_10_16_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=7.1.2 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (10.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (2.1.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (0.16.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (2.1.1)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Obtaining dependency information for seaborn>=0.11.0 from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: psutil in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.7.1)
# Requirement already satisfied: sympy in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2023.9.2)
# Requirement already satisfied: six>=1.5 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/hongdagyeong/opt/anaconda3/envs/torch/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.0.207-py3-none-any.whl (645 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 10.3 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_10_16_x86_64.whl (54.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 MB 24.4 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, opencv-python, thop, seaborn, ultralytics
# Successfully installed opencv-python-4.8.1.78 py-cpuinfo-9.0.0 seaborn-0.13.0 thop-0.1.1.post2209072238 ultralytics-8.0.207

# %% [markdown]
# ## 사용
# - CLI (command line interface)에서 터미널 명령어로 추론/평가/학습을 진행할 수 있다.
# - Python lib 를 이용해 코드상에 원하는 추론/평가/학습을 진행할 수 있다.

# %% [markdown]
# # CLI 기본 명령어 구조
#
# - 구문
#     - <span style='font-size:1.3em'>**yolo**  **task**=detect|classify|segment|pose  **mode**=train|val|predict  **model**=yolov8n.yaml|yolov8n.pt|..  **args**</span>
#     - <b style='font-size:1.2em'>task:</b> \[detect, classify, segment\] 중 하나를 지정한다. \[optional\]로 생략하면 모델을 보고 추측해서 task를 정한다.
#         - **detect:** Object detection
#         - **classify:** Image classification
#         - **segment:** Instance segmentation
#         - **pose:** Pose estimation
#     - <b style='font-size:1.2em'>mode:</b> \[train, val, predict, export\] 중 하나를 지정한다. \[필수\]로 입력해야 한다.
#         - **train:** custom dataset을 train 시킨다.
#         - **val:** 모델 성능을 평가한다.
#         - **predict:** 입력 이미지에 대한 추론을 한다.
#         - **export:** 모델을 다른 형식으로 변환한다.
#     - <b style='font-size:1.2em'>model:</b> **pretrained 모델**이나 **모델 설정 yaml 파일**의 경로를 설정한다. \[필수\]로 입력해야 한다.
#         - pretrained 모델 파일경로
#             - task에 맞는 pretrained 모델파일의 저장 경로를 지정한다.
#             - transfer learnging을 하거나 fine tuning 시 방법
#         - 모델 구조 설정 yaml 파일 경로
#             - task에 맞는 pretrained 모델 설정파일(yaml파일)의 경로를 지정한다.
#             - train mode에서 지정하며 모델을 새로 생성해서 처음부터 학습 시킬 경우 지정한다.
#         - Ultralytics에서 제공하는 Pretrained 모델
#             - 모델 크기에 따라 5개의 모델을 제공하며 큰 모델은 작은 모델에 비해 추론 성능이 좋은대신 속도는 느리다.
#             - 모델은 처음 추론또는 학습할때 local 컴퓨터에 없으면 download 받는다.
#             - https://github.com/ultralytics/ultralytics#models
#             - ### 제공 모델
#
#             | **task\모델크기**           | **nano** | **small** | **medium** | **large** | **xlarge** |
#             |:--------------------|----------|-------------|------------|-----------|----------|
#             | **detection**      | yolov8n  | yolov8s     | yolov8m    | yolov8l   | yolov8x    |
#             | **segmentation**   | yolov8n-seg  | yolov8s-seg     | yolov8m-seg    | yolov8l-seg   | yolov8x-seg    |
#             | **classification** | yolov8n-cls  | yolov8s-cls     | yolov8m-cls    | yolov8l-cls   | yolov8x-cls    |
#
#             - 확장자가 `pt`이면 pretrained 된 모델을, `yaml`이면 모델 구조 설정파일을 download하여 실행한다.
#                 - pretrained model은 fine tuning이나 추론할 때, yaml설정파일은 처음부터 학습할 경우 설정하여 받는다.
#     - <b style='font-size:1.2em'>args:</b> task와 mode과 관련한 추가 설정값들을 지정한다.
#         - https://docs.ultralytics.com/cfg/

# %% [markdown]
# # [Object Detection](https://docs.ultralytics.com/tasks/detection/)

# %% [markdown]
# ##  Predict (추론)
#
# ### 모델로딩
# - Ultralytics에서 제공하는 Pretrained Model이나 직접 학습시킨 모델을 이용해 추론한다.
# - Ultralytics는 Object Detection을 위한 [Pretrained 모델](#제공-모델)을 제공한다.
#     - Object Detection 모델은 COCO dataset으로 학습되었다.
#     - 모델 명을 지정하면 자동으로 다운로드를 받는다.

# %% [markdown]
# ### CLI
# `yolo task=detect mode=predict model=model_path source=추론할_image_path`
# - 추가 설정 (configuration)
#     - https://docs.ultralytics.com/cfg

# %% [markdown]
# > - argument 설정은 `name=value` 형식으로 한다. (`--name value`나 `name value` 는 안된다.)
#
# > ### 추론 할 Source 타입
# > - https://docs.ultralytics.com/modes/predict/#inference-sources
# > - **Image:** 이미지파일경로, URL, PIL.Image, np.ndarray, torch.Tensor
# > - **동영상:** 동영상파일경로, 유튜브 URL, 웹캠
# > - **여러개의 영상처리:** 디렉토리 경로 또는 경로들을 원소로 가지는 리스트.

# %%
yolo task=detect mode=predict model=models/yolov8s.pt source=01_test_image/1.jpg save=True save_txt=True line_width=1

# %%
yolo task=detect  # 어떤 작업을 할지
     mode=predict  # 그 작업 안에서 어떤 일을 할지
     model=models/yolov8s.pt  # fine tuning시 사용할 모델
     # 옵션
     source=01_test_image/1.jpg  # mode=predict에서 추론할 대상경로
     save=True  # 결과를 표현한 이미지 저장 여부 
     save_txt=True  # 결과 라벨파일 저장 여부
     line_width=1  # bounding box(bbox) 선 굵기
     conf=0.7  # confidence threshold (c_score가 지정한 값 이상인 것만 나옴)

# %%
yolo task=detect mode=predict model=models/yolov8n.pt 
     source=0 # 정수-web cam id
     show=True save=True

# %%
yolo task=detect mode=predict model=models/yolov8n.pt source=01_test_image/indo_street.mp4 save=True

# %% [markdown]
# ### Python

# %%
import ultralytics
from ultralytics import YOLO  # 모델 클래스

ultralytics.__version__
# Out:
# '8.0.207'

# %%
# 모델 생성
model = YOLO('models/yolov8n.pt')  # 객체 생성시 pretrained 모델 파일의 경로를 지정 (없으면 다운로드)
                                 # task => 설정한 모델 파일에 따라서 결정

# 추론
image_path = '01_test_image/1.jpg'
results = model(image_path)  # 추론 -> 필요한 설정들을 파라미터로 지정
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/1.jpg: 480x640 6 persons, 2 bicycles, 5 cars, 2 motorcycles, 1 bus, 3 traffic lights, 1 dog, 1 handbag, 422.2ms
# Speed: 11.4ms preprocess, 422.2ms inference, 36.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
print(type(results))  # 추론한 사진별로 결과를 따로 생성한 뒤에 리스트로 묶어줌
print(len(results))
print(type(results[0]))  # 첫번째 이미지에 대한 결과
# Out:
# <class 'list'>
# 1
# <class 'ultralytics.engine.results.Results'>

# %%
import matplotlib.pyplot as plt
import cv2

plt.imshow(results[0].plot()[:,:,::-1])  # 원본이미지에 추론 결과를 표시한 결과 이미지를 반환 (ndarray: bgr mode)
plt.show()

# %%
cv2.imshow('f', results[0].plot())
cv2.waitkey()
cv2.destroyAllWindows()

# %%
r = model(image_path, save=True, save_txt=True
          conf=0.7)
# Out:
# image 1/1 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/1.jpg: 480x640 6 persons, 2 bicycles, 5 cars, 2 motorcycles, 1 bus, 3 traffic lights, 1 dog, 1 handbag, 172.4ms
# Speed: 4.3ms preprocess, 172.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4

# %%
# web상 이미지 추론 -> url 지정 => 현재작업 디렉토리에 다운로드 후 추론
url = 'https://image.dongascience.com/Photo/2020/03/5bddba7b6574b95d37b6079c199d7101.jpg'
r = model(url, save=True)

# %% [markdown]
# ## 한번에 여러장 추론
# - 이미지들이 있는 디렉토리 경로를 전달
# - 추론할 파일경로를 리스트로 묶어서 추론한다.
#     - <del>이 경우 추론성능이 좋지 않은 경우가 생긴다.</del> (YOLO 초기 버전)

# %%
from glob import glob
img_list = glob('01_test_image/*.jpg')
img_list
# Out:
# ['01_test_image/4.jpg',
#  '01_test_image/5.jpg',
#  '01_test_image/6.jpg',
#  '01_test_image/2.jpg',
#  '01_test_image/3.jpg',
#  '01_test_image/1.jpg']

# %%
r = model(img_list, save=True)
# Out:
# 0: 640x640 2 elephants, 1 zebra, 1: 640x640 9 persons, 1 bottle, 12 wine glasss, 2 cups, 1 bowl, 1 dining table, 2: 640x640 3 persons, 1 cup, 1 knife, 3 pizzas, 1 dining table, 3: 640x640 13 persons, 3 cars, 3 buss, 1 truck, 2 traffic lights, 4: 640x640 1 cup, 1 chair, 1 tv, 1 mouse, 1 keyboard, 2 cell phones, 1 vase, 5: 640x640 5 persons, 3 bicycles, 4 cars, 1 motorcycle, 1 bus, 3 traffic lights, 1 dog, 1 handbag, 1536.2ms
# Speed: 10.8ms preprocess, 256.0ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %%
r2 = model('02_test_image/', save=True)  # 리스트
# Out:
# image 1/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/apple.jpg: 416x640 1 bowl, 6 apples, 1 dining table, 110.3ms
# image 2/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/banana.jpg: 384x640 1 banana, 97.1ms
# image 3/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/banana2.jpg: 640x640 1 banana, 174.3ms
# image 4/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/capsicum1.jpg: 640x640 2 vases, 305.4ms
# image 5/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/capsicum2.jpg: 480x640 (no detections), 203.2ms
# image 6/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/eggplant.jpg: 480x640 (no detections), 216.8ms
# image 7/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/grape.jpg: 384x640 2 apples, 166.0ms
# image 8/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/melon1.jpg: 640x608 (no detections), 243.1ms
# image 9/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/melon2.jpg: 640x640 3 oranges, 1 vase, 263.2ms
# image 10/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/pineapple.jpg: 512x640 1 donut, 224.7ms
# image 11/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/pineapple2.jpg: 480x640 (no detections), 209.7ms
# image 12/12 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/02_test_image/pomegranate.jpg: 448x640 1 apple, 1 vase, 186.1ms
# Speed: 3.2ms preprocess, 200.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4

# %%
len(r2)  # 추론한 대상 이미지의 개수
# r2[0]  # 첫번째 이미지 결과
# r2[-1]  # 마지막 이미지 결과
# Out:
# 12

# %% [markdown]
# ## 동영상
# - source에 동영상 파일 경로를 지정한다.
#     - frame 단위로 추론한다.

# %%
r = model('01_test_image/indo_street.mp4',
          # save=True, show=True
         )
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bench, 1 umbrella, 154.9ms
# video 1/1 (2/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bench, 2 umbrellas, 108.5ms
# video 1/1 (3/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bench, 1 umbrella, 148.6ms
# video 1/1 (4/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 158.1ms
# video 1/1 (5/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bench, 1 umbrella, 169.2ms
# video 1/1 (6/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 161.5ms
# video 1/1 (7/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 umbrellas, 188.1ms
# video 1/1 (8/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 170.5ms
# video 1/1 (9/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 umbrella, 161.3ms
# video 1/1 (10/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 6 persons, 1 motorcycle, 1 umbrella, 173.9ms
# video 1/1 (11/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 umbrella, 176.9ms
# video 1/1 (12/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 umbrella, 172.8ms
# video 1/1 (13/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 164.0ms
# video 1/1 (14/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 motorcycle, 1 umbrella, 166.9ms
# video 1/1 (15/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 umbrella, 165.8ms
# video 1/1 (16/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 car, 1 umbrella, 162.7ms
# video 1/1 (17/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 motorcycle, 1 umbrella, 168.8ms
# video 1/1 (18/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 163.0ms
# video 1/1 (19/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 umbrella, 167.0ms
# video 1/1 (20/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 umbrella, 163.2ms
# video 1/1 (21/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 umbrella, 162.1ms
# video 1/1 (22/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 168.4ms
# video 1/1 (23/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 161.5ms
# video 1/1 (24/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 178.9ms
# video 1/1 (25/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 168.6ms
# video 1/1 (26/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 164.9ms
# video 1/1 (27/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 bicycle, 1 umbrella, 162.0ms
# video 1/1 (28/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 183.9ms
# video 1/1 (29/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bicycle, 1 umbrella, 166.6ms
# video 1/1 (30/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 bicycle, 1 umbrella, 170.4ms
# video 1/1 (31/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 umbrella, 165.0ms
# video 1/1 (32/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 2 bicycles, 1 umbrella, 167.5ms
# video 1/1 (33/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 2 bicycles, 1 umbrella, 173.5ms
# video 1/1 (34/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 bicycle, 1 umbrella, 195.9ms
# video 1/1 (35/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bicycle, 1 umbrella, 184.5ms
# video 1/1 (36/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bicycle, 1 umbrella, 1 handbag, 169.3ms
# video 1/1 (37/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bicycle, 1 umbrella, 168.5ms
# video 1/1 (38/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bicycle, 1 bus, 1 backpack, 1 umbrella, 1 handbag, 169.0ms
# video 1/1 (39/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 bicycle, 1 motorcycle, 1 umbrella, 168.6ms
# video 1/1 (40/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bicycle, 1 bus, 1 umbrella, 166.4ms
# video 1/1 (41/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 bicycle, 1 bus, 1 umbrella, 171.2ms
# video 1/1 (42/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bicycle, 1 bus, 1 umbrella, 1 handbag, 169.5ms
# video 1/1 (43/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 bicycles, 1 umbrella, 166.0ms
# video 1/1 (44/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bicycle, 1 umbrella, 169.0ms
# video 1/1 (45/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 bicycle, 1 umbrella, 1 handbag, 170.0ms
# video 1/1 (46/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 bicycles, 1 backpack, 1 umbrella, 166.2ms
# video 1/1 (47/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bicycle, 1 umbrella, 173.9ms
# video 1/1 (48/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 handbag, 163.9ms
# video 1/1 (49/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 167.1ms
# video 1/1 (50/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 166.9ms
# video 1/1 (51/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 168.5ms
# video 1/1 (52/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 dining table, 167.4ms
# video 1/1 (53/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 dining table, 166.6ms
# video 1/1 (54/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 dining table, 168.9ms
# video 1/1 (55/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 dining table, 168.2ms
# video 1/1 (56/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 dining table, 166.3ms
# video 1/1 (57/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 166.5ms
# video 1/1 (58/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 180.8ms
# video 1/1 (59/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 160.9ms
# video 1/1 (60/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 166.4ms
# video 1/1 (61/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 167.5ms
# video 1/1 (62/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 159.2ms
# video 1/1 (63/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 169.8ms
# video 1/1 (64/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 160.0ms
# video 1/1 (65/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 164.5ms
# video 1/1 (66/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 174.5ms
# video 1/1 (67/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 169.1ms
# video 1/1 (68/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 158.9ms
# video 1/1 (69/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 172.5ms
# video 1/1 (70/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 172.8ms
# video 1/1 (71/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 164.7ms
# video 1/1 (72/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 1 chair, 169.3ms
# video 1/1 (73/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 chair, 168.7ms
# video 1/1 (74/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 chair, 165.4ms
# video 1/1 (75/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 chair, 163.3ms
# video 1/1 (76/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 166.9ms
# video 1/1 (77/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 bus, 1 umbrella, 168.6ms
# video 1/1 (78/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 umbrella, 166.5ms
# video 1/1 (79/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 bus, 1 umbrella, 165.1ms
# video 1/1 (80/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bus, 1 umbrella, 171.7ms
# video 1/1 (81/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bus, 1 umbrella, 161.1ms
# video 1/1 (82/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bus, 1 umbrella, 165.5ms
# video 1/1 (83/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bus, 1 umbrella, 171.9ms
# video 1/1 (84/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 163.3ms
# video 1/1 (85/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 1 dining table, 167.8ms
# video 1/1 (86/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 161.8ms
# video 1/1 (87/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 1 dining table, 168.6ms
# video 1/1 (88/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 161.5ms
# video 1/1 (89/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 162.6ms
# video 1/1 (90/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 171.0ms
# video 1/1 (91/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bus, 1 umbrella, 162.9ms
# video 1/1 (92/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 bus, 1 umbrella, 165.4ms
# video 1/1 (93/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bus, 1 umbrella, 1 chair, 166.0ms
# video 1/1 (94/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 bus, 1 umbrella, 169.3ms
# video 1/1 (95/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 motorcycle, 1 umbrella, 1 chair, 163.4ms
# video 1/1 (96/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 1 chair, 164.2ms
# video 1/1 (97/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 motorcycle, 1 umbrella, 1 chair, 169.2ms
# video 1/1 (98/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 2 motorcycles, 1 umbrella, 1 chair, 164.3ms
# video 1/1 (99/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 motorcycle, 1 umbrella, 1 chair, 165.3ms
# video 1/1 (100/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 motorcycle, 1 umbrella, 1 chair, 166.2ms
# video 1/1 (101/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 motorcycle, 1 umbrella, 1 chair, 167.0ms
# video 1/1 (102/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 7 persons, 1 umbrella, 1 chair, 169.7ms
# video 1/1 (103/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 chair, 161.3ms
# video 1/1 (104/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 1 chair, 163.7ms
# video 1/1 (105/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 1 chair, 166.2ms
# video 1/1 (106/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 164.5ms
# video 1/1 (107/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 1 chair, 166.3ms
# video 1/1 (108/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 1 chair, 172.1ms
# video 1/1 (109/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 1 chair, 161.8ms
# video 1/1 (110/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 1 chair, 165.9ms
# video 1/1 (111/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 1 chair, 165.2ms
# video 1/1 (112/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 1 chair, 166.8ms
# video 1/1 (113/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 164.1ms
# video 1/1 (114/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 164.7ms
# video 1/1 (115/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 164.4ms
# video 1/1 (116/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 168.8ms
# video 1/1 (117/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 175.8ms
# video 1/1 (118/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 169.4ms
# video 1/1 (119/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 169.2ms
# video 1/1 (120/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 167.9ms
# video 1/1 (121/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 161.0ms
# video 1/1 (122/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 162.9ms
# video 1/1 (123/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 166.6ms
# video 1/1 (124/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 168.8ms
# video 1/1 (125/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 162.9ms
# video 1/1 (126/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 164.0ms
# video 1/1 (127/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 167.2ms
# video 1/1 (128/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 170.1ms
# video 1/1 (129/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 161.9ms
# video 1/1 (130/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 173.7ms
# video 1/1 (131/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 165.0ms
# video 1/1 (132/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 173.6ms
# video 1/1 (133/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 17 persons, 1 motorcycle, 1 umbrella, 167.2ms
# video 1/1 (134/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 166.4ms
# video 1/1 (135/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 17 persons, 1 motorcycle, 1 umbrella, 171.1ms
# video 1/1 (136/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 161.5ms
# video 1/1 (137/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 17 persons, 1 umbrella, 168.0ms
# video 1/1 (138/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 bicycle, 1 motorcycle, 1 umbrella, 168.8ms
# video 1/1 (139/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 18 persons, 1 umbrella, 161.2ms
# video 1/1 (140/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 169.3ms
# video 1/1 (141/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 1 chair, 165.4ms
# video 1/1 (142/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 1 chair, 163.6ms
# video 1/1 (143/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 162.8ms
# video 1/1 (144/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 164.9ms
# video 1/1 (145/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 1 chair, 165.4ms
# video 1/1 (146/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 166.4ms
# video 1/1 (147/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 174.5ms
# video 1/1 (148/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 164.0ms
# video 1/1 (149/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 168.8ms
# video 1/1 (150/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 174.7ms
# video 1/1 (151/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 195.5ms
# video 1/1 (152/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 2 motorcycles, 1 umbrella, 180.4ms
# video 1/1 (153/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 176.0ms
# video 1/1 (154/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 180.7ms
# video 1/1 (155/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 198.8ms
# video 1/1 (156/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 umbrella, 186.1ms
# video 1/1 (157/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 umbrella, 176.4ms
# video 1/1 (158/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 157.6ms
# video 1/1 (159/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 174.1ms
# video 1/1 (160/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 2 motorcycles, 1 umbrella, 179.9ms
# video 1/1 (161/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 2 motorcycles, 1 umbrella, 160.7ms
# video 1/1 (162/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 167.7ms
# video 1/1 (163/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 169.1ms
# video 1/1 (164/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 2 motorcycles, 1 umbrella, 174.1ms
# video 1/1 (165/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 2 motorcycles, 1 umbrella, 162.4ms
# video 1/1 (166/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 2 motorcycles, 1 umbrella, 164.1ms
# video 1/1 (167/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 162.8ms
# video 1/1 (168/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 155.5ms
# video 1/1 (169/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 162.2ms
# video 1/1 (170/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 potted plant, 165.8ms
# video 1/1 (171/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 160.3ms
# video 1/1 (172/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 18 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 166.8ms
# video 1/1 (173/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 164.4ms
# video 1/1 (174/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 162.5ms
# video 1/1 (175/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 3 motorcycles, 1 umbrella, 1 potted plant, 163.6ms
# video 1/1 (176/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 4 motorcycles, 1 umbrella, 1 potted plant, 156.6ms
# video 1/1 (177/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 4 motorcycles, 1 umbrella, 1 potted plant, 162.8ms
# video 1/1 (178/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 4 motorcycles, 1 umbrella, 1 potted plant, 163.0ms
# video 1/1 (179/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 3 motorcycles, 1 umbrella, 1 potted plant, 156.6ms
# video 1/1 (180/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 3 motorcycles, 1 umbrella, 1 potted plant, 165.4ms
# video 1/1 (181/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 3 motorcycles, 1 umbrella, 1 potted plant, 159.3ms
# video 1/1 (182/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 154.4ms
# video 1/1 (183/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 163.6ms
# video 1/1 (184/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 156.0ms
# video 1/1 (185/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 159.7ms
# video 1/1 (186/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 167.9ms
# video 1/1 (187/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 potted plant, 158.6ms
# video 1/1 (188/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 3 motorcycles, 1 umbrella, 1 potted plant, 159.5ms
# video 1/1 (189/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 umbrella, 1 chair, 1 potted plant, 158.9ms
# video 1/1 (190/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 4 motorcycles, 1 umbrella, 1 potted plant, 163.9ms
# video 1/1 (191/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 156.0ms
# video 1/1 (192/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 potted plant, 157.9ms
# video 1/1 (193/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 chair, 1 potted plant, 160.3ms
# video 1/1 (194/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 156.5ms
# video 1/1 (195/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 160.1ms
# video 1/1 (196/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 2 motorcycles, 1 umbrella, 1 potted plant, 165.4ms
# video 1/1 (197/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 3 motorcycles, 1 umbrella, 165.6ms
# video 1/1 (198/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 160.8ms
# video 1/1 (199/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 2 motorcycles, 1 umbrella, 154.5ms
# video 1/1 (200/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 2 motorcycles, 1 umbrella, 158.7ms
# video 1/1 (201/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 3 motorcycles, 1 umbrella, 155.9ms
# video 1/1 (202/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 2 motorcycles, 1 umbrella, 160.6ms
# video 1/1 (203/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 2 motorcycles, 1 umbrella, 158.4ms
# video 1/1 (204/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 motorcycle, 1 umbrella, 158.1ms
# video 1/1 (205/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 17 persons, 1 motorcycle, 1 umbrella, 158.3ms
# video 1/1 (206/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 motorcycle, 1 umbrella, 156.0ms
# video 1/1 (207/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 1 potted plant, 157.7ms
# video 1/1 (208/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 1 potted plant, 158.1ms
# video 1/1 (209/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 1 potted plant, 162.2ms
# video 1/1 (210/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 potted plant, 157.3ms
# video 1/1 (211/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 potted plant, 156.9ms
# video 1/1 (212/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 156.5ms
# video 1/1 (213/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 1 handbag, 163.1ms
# video 1/1 (214/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 151.5ms
# video 1/1 (215/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 156.9ms
# video 1/1 (216/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 164.4ms
# video 1/1 (217/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 154.0ms
# video 1/1 (218/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 159.7ms
# video 1/1 (219/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 154.1ms
# video 1/1 (220/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 1 potted plant, 155.8ms
# video 1/1 (221/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bicycle, 1 umbrella, 1 potted plant, 159.0ms
# video 1/1 (222/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bicycle, 1 umbrella, 1 potted plant, 156.4ms
# video 1/1 (223/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 potted plant, 158.2ms
# video 1/1 (224/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 1 potted plant, 153.2ms
# video 1/1 (225/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 160.8ms
# video 1/1 (226/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 1 potted plant, 155.2ms
# video 1/1 (227/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 potted plant, 155.6ms
# video 1/1 (228/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 17 persons, 1 bicycle, 1 umbrella, 1 potted plant, 154.2ms
# video 1/1 (229/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 159.7ms
# video 1/1 (230/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 154.6ms
# video 1/1 (231/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 156.7ms
# video 1/1 (232/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 156.4ms
# video 1/1 (233/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 161.1ms
# video 1/1 (234/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 2 bicycles, 1 umbrella, 155.9ms
# video 1/1 (235/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 umbrella, 157.2ms
# video 1/1 (236/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 umbrella, 159.6ms
# video 1/1 (237/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bicycle, 1 umbrella, 155.3ms
# video 1/1 (238/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 umbrella, 156.5ms
# video 1/1 (239/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 umbrella, 155.5ms
# video 1/1 (240/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 umbrella, 154.2ms
# video 1/1 (241/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 218.1ms
# video 1/1 (242/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 164.3ms
# video 1/1 (243/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 bicycles, 1 bus, 1 umbrella, 157.2ms
# video 1/1 (244/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 158.5ms
# video 1/1 (245/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 dining table, 158.4ms
# video 1/1 (246/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 157.4ms
# video 1/1 (247/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 horse, 1 umbrella, 1 dining table, 160.1ms
# video 1/1 (248/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 1 dining table, 159.1ms
# video 1/1 (249/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 156.5ms
# video 1/1 (250/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 160.9ms
# video 1/1 (251/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 155.0ms
# video 1/1 (252/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 161.0ms
# video 1/1 (253/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 161.6ms
# video 1/1 (254/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 161.6ms
# video 1/1 (255/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 156.6ms
# video 1/1 (256/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 umbrella, 157.2ms
# ...
# video 1/1 (266/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 umbrella, 162.6ms
# video 1/1 (267/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 19 persons, 1 umbrella, 156.0ms
# video 1/1 (268/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 umbrella, 155.9ms
# video 1/1 (269/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bicycle, 1 bus, 1 umbrella, 158.6ms
# video 1/1 (270/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bicycle, 1 bus, 1 umbrella, 158.2ms
# video 1/1 (271/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 16 persons, 1 bicycle, 1 bus, 1 umbrella, 161.0ms
# video 1/1 (272/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bicycle, 1 bus, 1 umbrella, 158.8ms
# video 1/1 (273/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 bus, 1 umbrella, 158.9ms
# video 1/1 (274/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bus, 1 umbrella, 157.0ms
# video 1/1 (275/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bus, 1 umbrella, 156.4ms
# video 1/1 (276/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bus, 1 umbrella, 160.3ms
# video 1/1 (277/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bus, 1 truck, 1 umbrella, 155.0ms
# video 1/1 (278/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bus, 1 umbrella, 159.6ms
# video 1/1 (279/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 2 bicycles, 1 motorcycle, 1 umbrella, 155.5ms
# video 1/1 (280/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bus, 1 umbrella, 157.6ms
# video 1/1 (281/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bicycle, 1 umbrella, 157.8ms
# video 1/1 (282/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 umbrella, 153.7ms
# video 1/1 (283/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 umbrella, 157.2ms
# video 1/1 (284/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 158.9ms
# video 1/1 (285/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 154.0ms
# video 1/1 (286/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 bicycle, 1 umbrella, 158.6ms
# video 1/1 (287/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 umbrella, 159.7ms
# video 1/1 (288/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 152.5ms
# video 1/1 (289/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 161.3ms
# video 1/1 (290/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 156.6ms
# video 1/1 (291/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 motorcycle, 1 umbrella, 156.7ms
# video 1/1 (292/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 159.6ms
# video 1/1 (293/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 157.0ms
# video 1/1 (294/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 157.5ms
# video 1/1 (295/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 157.9ms
# video 1/1 (296/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 156.0ms
# video 1/1 (297/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 157.0ms
# video 1/1 (298/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 umbrella, 157.6ms
# video 1/1 (299/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 umbrella, 156.2ms
# video 1/1 (300/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 157.8ms
# video 1/1 (301/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 umbrella, 159.7ms
# video 1/1 (302/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 umbrella, 156.8ms
# video 1/1 (303/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 158.6ms
# video 1/1 (304/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 160.4ms
# video 1/1 (305/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 umbrella, 155.7ms
# video 1/1 (306/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 159.8ms
# video 1/1 (307/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 umbrella, 157.3ms
# video 1/1 (308/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 2 motorcycles, 1 umbrella, 160.6ms
# video 1/1 (309/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 159.5ms
# video 1/1 (310/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 bicycle, 1 motorcycle, 1 umbrella, 154.3ms
# video 1/1 (311/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 motorcycle, 1 umbrella, 158.9ms
# video 1/1 (312/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 umbrella, 158.7ms
# video 1/1 (313/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 15 persons, 1 bicycle, 2 motorcycles, 1 umbrella, 157.0ms
# video 1/1 (314/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 motorcycle, 1 umbrella, 154.6ms
# video 1/1 (315/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 umbrella, 157.3ms
# video 1/1 (316/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 159.2ms
# video 1/1 (317/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 umbrella, 157.3ms
# video 1/1 (318/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 bicycle, 1 umbrella, 160.6ms
# video 1/1 (319/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 1 chair, 164.0ms
# video 1/1 (320/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 bus, 1 umbrella, 154.4ms
# video 1/1 (321/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 1 bicycle, 1 umbrella, 157.9ms
# video 1/1 (322/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 umbrella, 159.3ms
# video 1/1 (323/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 13 persons, 1 umbrella, 169.9ms
# video 1/1 (324/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 bicycle, 1 umbrella, 161.9ms
# video 1/1 (325/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 4 bicycles, 1 umbrella, 161.7ms
# video 1/1 (326/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 bicycle, 1 umbrella, 1 dining table, 165.5ms
# video 1/1 (327/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 bicycles, 1 umbrella, 1 dining table, 157.8ms
# video 1/1 (328/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 8 persons, 1 umbrella, 1 dining table, 160.3ms
# video 1/1 (329/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 dining table, 156.5ms
# video 1/1 (330/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 dining table, 162.7ms
# video 1/1 (331/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 1 motorcycle, 1 umbrella, 1 dining table, 153.7ms
# video 1/1 (332/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 1 motorcycle, 1 umbrella, 1 dining table, 155.8ms
# video 1/1 (333/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 1 motorcycle, 1 bus, 1 umbrella, 1 dining table, 162.5ms
# video 1/1 (334/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 bus, 1 umbrella, 1 dining table, 154.8ms
# video 1/1 (335/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 motorcycles, 1 bus, 1 dining table, 158.8ms
# video 1/1 (336/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 motorcycles, 1 bus, 1 umbrella, 1 dining table, 163.6ms
# video 1/1 (337/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 motorcycles, 1 bus, 1 umbrella, 159.6ms
# video 1/1 (338/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 motorcycles, 1 umbrella, 159.7ms
# video 1/1 (339/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 9 persons, 2 motorcycles, 154.6ms
# video 1/1 (340/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 158.2ms
# video 1/1 (341/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 157.2ms
# video 1/1 (342/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 157.3ms
# video 1/1 (343/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 14 persons, 2 motorcycles, 1 bus, 163.4ms
# video 1/1 (344/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 1 bus, 157.1ms
# video 1/1 (345/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 1 motorcycle, 157.3ms
# video 1/1 (346/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 12 persons, 2 motorcycles, 155.6ms
# video 1/1 (347/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 bus, 1 umbrella, 157.2ms
# video 1/1 (348/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 bus, 1 umbrella, 158.5ms
# video 1/1 (349/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 10 persons, 2 motorcycles, 1 bus, 1 umbrella, 154.4ms
# video 1/1 (350/350) /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/indo_street.mp4: 384x640 11 persons, 2 motorcycles, 1 bus, 1 umbrella, 158.7ms
# Speed: 1.6ms preprocess, 163.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
len(r)
# Out:
# 350

# %%
r = model(0,  # 정수: 웹캠 id
          show=True)

# %% [markdown]
# ## 추론결과

# %% [markdown]
# ### ultralytics.yolo.engine.results.Results
# - 모델의 추론 결과는 list에 이미지별 예측결과를 Results에 담아 반환한다.
# - **Results** : 한개 이미지에 대한 추론결과를 담는 객체
# - 추론 종류에 따라 다음 속성을 이용해 결과를 조회한다.
#     - Detection: **`result.boxes`** - Boxes type
#     - Segmentation: **`result.masks`** - Masks type
#     - Classification: **`result.probs`** - torch.Tensor type
#     - Pose estimator: **`result.keypoints`** - Keypoints  type
# - 추가 정보
#     - Results.orig_img: 추론한 원본 이미지
#     - Results.orig_shape: 추론한 원본 이미지의 크기 (height, width)
#     - Results.path: 추론한 원본이미지의 경로
#     - Results.names: class2classname 정의한 딕셔너리 (key: 클래스, name: 클래스 이름)
# - 메소드
#     - Results.plot(): 원본 이미지에 추론결과를 표현한 이미지를 ndarray로 반환 (opencv를 이용해서 만들기 때문에 BGR모드로 반환)

# %%
import os
os.getcwd()
# Out:
# '/Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam'

# %%
from ultralytics import YOLO

model = YOLO('models/yolov8s.pt')
result_list = model('01_test_image/1.jpg', conf=0.7)
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/1.jpg: 480x640 3 persons, 2 cars, 1 motorcycle, 1 bus, 1 dog, 730.8ms
# Speed: 7.4ms preprocess, 730.8ms inference, 24.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
print('총 이미지수:', len(result_list))
result = result_list[0]  # 첫번째 이미지에 대한 결과
# Out:
# 총 이미지수: 1

# %%
print('원본이미지 경로: ', result.path)
print('원본이미지 size: ', result.orig_shape)  # (height, width)
print('원본이미지: ', result.orig_img, result.orig_img.shape, result.orig_img.dtype)
import matplotlib.pyplot as plt

plt.imshow(result.orig_img)
# Out:
# 원본이미지 경로:  /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/1.jpg
# 원본이미지 size:  (480, 640)
# 원본이미지:  [[[200 232 231]
#   [200 232 231]
#   [200 232 231]
#   ...
#   [113 101  95]
#   [ 95  97  85]
#   [144 155 139]]
#
#  [[201 232 231]
#   [200 232 231]
#   [200 232 231]
#   ...
#   [103  91  85]
#   [ 83  85  73]
#   [151 162 146]]
#
#  [[203 231 231]
#   [201 232 231]
#   [201 232 229]
#   ...
#   [118 106 100]
#   [ 80  82  70]
#   [152 163 147]]
#
#  ...
#
#  [[ 49  40  27]
#   [ 51  42  29]
#   [ 51  41  31]
#   ...
#   [ 76  69  52]
#   [ 72  65  48]
#   [ 61  54  37]]
#
#  [[ 38  28  18]
#   [ 36  26  16]
#   [ 36  26  16]
#   ...
#   [ 64  58  39]
#   [ 63  57  38]
#   [ 64  58  39]]
#
#  [[ 86  76  66]
#   [ 82  72  62]
#   [ 80  70  60]
#   ...
#   [ 95  89  70]
#   [100  94  75]
#   [111 105  86]]] (480, 640, 3) uint8

# %%
# class
from pprint import pprint  # 자료구조를 보기좋게 출력하는 함수
pprint(result.names)  # key: index(class), name: class name  ==> 모델이 학습한 데이터의 idx2class를 반환
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### Object Detection 결과값 조회
#
# - ultralytics.yolo.engine.results.**Boxes**에 추론 결과를 담아 반환
#     - Results.boxes로 조회
# - 주요 속성
#     - shape: 결과 shape. (찾은 물체개수, 6)
#     - boxes
#         - 6: 좌상단 x, 좌상단 y, 우하단 x, 우하단 y, confidence score, label
#     - xyxy
#         - bounding box의 `좌상단 x, 좌상단 y, 우하단 x, 우하단 y` 좌표 반환
#     - xyxyn
#         - xyxy를 이미지 대비 비율로 반환
#     - xywh
#         - bounding box의 `center x, center y, 너비, 높이` 를 반환
#     - xywhn
#         - xywh를 이미지 대비 비율로 반환
#     - cls: 찾은 물체의 label
#     - conf: cls에 대한 confidence score (그 물체일 확률)
#
#
#
#
# > - 0차원 torch.Tensor 를 상수로 변환
# >     - `tensor.item()`
# > - N차원 torch.Tensor를 ndarray로 변환
# >     - `tensor.numpy()`
# >     - Tensor객체가 GPU메모리에 있을 경우 메인메모리(CPU)로 먼저 옮겨야 한다.
# >         - `tensor.to('cpu')` or `tensor.cpu()`

# %%
# result_list[0]
boxes = result.boxes
print(type(boxes))  # Object Detection 결과 -> bbox 위치와 object class
# Out:
# <class 'ultralytics.engine.results.Boxes'>

# %%
print(boxes.conf.shape)  # 찾은 object의 class 확률
boxes.conf
# Out:
# torch.Size([8])
# tensor([0.9389, 0.9196, 0.8995, 0.8812, 0.8729, 0.8461, 0.7283, 0.7213])

# %%
# 찾은 object 정보
print(boxes.cls.shape)  # boxes.cls: object class(index) => [8] => 찾은 object 8개. 8개 class
print(boxes.cls)
for c, p in zip(boxes.cls, boxes.conf):
    print(f'{int(c)} - {result.names[c.item()]}, {p*100:.3f}%')
# Out:
# torch.Size([8])
# tensor([ 5.,  2.,  0.,  0.,  0.,  3.,  2., 16.])
# 5 - bus, 93.892%
# 2 - car, 91.958%
# 0 - person, 89.952%
# 0 - person, 88.116%
# 0 - person, 87.289%
# 3 - motorcycle, 84.606%
# 2 - car, 72.832%
# 16 - dog, 72.135%

# %%
## bbox 위치 - xyxy : 좌상단 x, y, 우하단 x, y 좌표
print(boxes.xyxy, boxes.xyxy.shape, sep='\n')  # shape: [8: 찾은 object 개수,  4: 좌표-좌상단xy, 우하단xy]
# Out:
# tensor([[8.5889e-01, 1.2250e+00, 2.5641e+02, 2.6216e+02],
#         [3.0653e+02, 1.6258e+02, 5.1737e+02, 2.8614e+02],
#         [1.8107e-01, 1.2493e+02, 1.1881e+02, 3.6624e+02],
#         [2.0170e+02, 1.4166e+02, 3.1828e+02, 4.7757e+02],
#         [5.1704e+02, 1.3033e+02, 5.9663e+02, 3.2384e+02],
#         [8.7936e-02, 1.9597e+02, 1.7282e+02, 3.5359e+02],
#         [2.7449e+02, 1.4545e+02, 3.6723e+02, 1.8393e+02],
#         [5.9504e+02, 2.7713e+02, 6.3965e+02, 3.5859e+02]])
# torch.Size([8, 4])

# %%
print(boxes.xyxyn, boxes.xyxyn.shape, sep='\n')  # 0 ~ 1 normalize(정규화) -> 이미지 크기 대비 비율
# Out:
# tensor([[1.3420e-03, 2.5520e-03, 4.0065e-01, 5.4617e-01],
#         [4.7896e-01, 3.3870e-01, 8.0840e-01, 5.9612e-01],
#         [2.8292e-04, 2.6026e-01, 1.8564e-01, 7.6300e-01],
#         [3.1516e-01, 2.9512e-01, 4.9732e-01, 9.9493e-01],
#         [8.0787e-01, 2.7152e-01, 9.3223e-01, 6.7467e-01],
#         [1.3740e-04, 4.0826e-01, 2.7004e-01, 7.3665e-01],
#         [4.2889e-01, 3.0302e-01, 5.7380e-01, 3.8319e-01],
#         [9.2975e-01, 5.7735e-01, 9.9945e-01, 7.4705e-01]])
# torch.Size([8, 4])

# %%
# bbox 위치 - xywh : center x, y 좌표, bbox의 너비, 높이
print(boxes.xywh, boxes.xywh.shape, sep='\n')
print(boxes.xywhn, boxes.xywhn.shape, sep='\n')  # xywhn => normalize
# Out:
# tensor([[128.6361, 131.6944, 255.5545, 260.9389],
#         [411.9542, 224.3557, 210.8400, 123.5591],
#         [ 59.4941, 245.5834, 118.6260, 241.3146],
#         [259.9919, 309.6126, 116.5818, 335.9064],
#         [556.8340, 227.0868,  79.5896, 193.5126],
#         [ 86.4553, 274.7800, 172.7346, 157.6271],
#         [320.8602, 164.6907,  92.7413,  38.4828],
#         [617.3450, 317.8557,  44.6074,  81.4589]])
# torch.Size([8, 4])
# tensor([[0.2010, 0.2744, 0.3993, 0.5436],
#         [0.6437, 0.4674, 0.3294, 0.2574],
#         [0.0930, 0.5116, 0.1854, 0.5027],
#         [0.4062, 0.6450, 0.1822, 0.6998],
#         [0.8701, 0.4731, 0.1244, 0.4032],
#         [0.1351, 0.5725, 0.2699, 0.3284],
#         [0.5013, 0.3431, 0.1449, 0.0802],
#         [0.9646, 0.6622, 0.0697, 0.1697]])
# torch.Size([8, 4])

# %%
# 원본 이미지에 bbox를 치고 class를 출력
import cv2
from ultralytics import YOLO 

# 1. 모델 생성
model = YOLO('models/yolov8s.pt')

# 2. 추론
result_list = model('01_test_image/1.jpg')
# 3. 추론결과를 이용한 추가 작업 ==> bbox 그리기

result = result_list[0]
# 원본이미지를 복사

org_img = result.orig_img
img = org_img.copy()

# bbox 추론결과를 조회
boxes = result.boxes
xyxy_list = boxes.xyxy  # 좌상단, 우하단 좌표 (bbox 위치)
cls_list = boxes.cls    # class index
conf_list = boxes.conf  # class 확률

# tensor -> ndarray 변환시 -> CPU로 이동시킨 후 변환 가능
for xyxy, cls, conf in zip(xyxy_list, cls_list, conf_list):
    pt1 = xyxy[:2].to('cpu').numpy().astype('int32')  # 좌상단 좌표
    pt2 = xyxy[2:].to('cpu').numpy().astype('int32')  # 우하단 좌표
    cls_name = result.names[int(cls.item())]
    txt = f"{cls_name}-{conf.item()*100:.2f}%"
    
    # image에 bbox
    cv2.rectangle(img, pt1=pt1, pt2=pt2, color=(255, 255, 255), thickness=1)
    # label text
    cv2.putText(img, text=txt, org=pt1-5, fontFace=cv2.FONT_HERSHEY_COMPLEX, fontScale=0.5,
                color=(255, 255, 255), thickness=1, lineType=cv2.LINE_AA)
    
# img 출력
cv2.imshow('result', img)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(0)
cv2.waitKey(0)
cv2.waitKey(0)
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /Users/hongdagyeong/Documents/Pd/playdata/09_Computer_Vision/object_detection_exam/01_test_image/1.jpg: 480x640 7 persons, 1 bicycle, 6 cars, 2 motorcycles, 2 buss, 3 traffic lights, 1 dog, 1 handbag, 490.6ms
# Speed: 5.9ms preprocess, 490.6ms inference, 20.9ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# # TODO
# - 웹캠 입력 디텍션

# %%
import cv2
from ultralytics import YOLO

# 웹캠연결
cap = cv2.VideoCapture(1)
# YOLO 모델 생성
model = YOLO('models/yolov8n.pt')

while cap.isOpened():
    # 한 frame(이미지)을 읽기
    succ, frame = cap.read()
    if not succ:
        print('웹캠 문제')
        break
    # filp(대칭)
    frame = cv2.flip(frame, 1)  # 양수: 좌우, 0: 상하, 음수: 상하좌우
    ################################################
    # YOLO 모델을 이용한 추론 -> 결과 이미지 생성
    ################################################
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # yolo는 rgb 이미지를 학습시킴
    # 추론 추론대상이미지타입 - 문자열(경로), Image(ndarray, PIL.Image)
    result = model(img,
                   conf=0.5,  # 확률이 0.5이상인 것만 결과로 리턴
                   verbose=False)[0]  # 추론 결과 로그를 출력하지 않음
    # 결과에서 위치, 클래스 정보 추출
    ### (찾은 object 개수, shape)
    xyxy_list = result.boxes.xyxy.to('cpu').numpy().astype('int32')
    cls_list = result.boxes.cls.to('cpu').numpy().astype('int32')
    conf_list = result.boxes.conf.to('cpu').numpy()
    
    # for in 문을 이용해 찾은 object 별로 bbox 처리를 함
    for xyxy, cls, conf in zip(xyxy_list, cls_list, conf_list):
        pt1, pt2 = xyxy[:2], xyxy[2:]
        txt = f'{result.names[cls]} - {conf*100:.3f}%'
        # box
        cv2.rectangle(frame, pt1, pt2, color=(255,0,0), thickness=2)
        cv2.putText(frame, txt, org=pt1,fontFace=cv2.FONT_HERSHEY_COMPLEX, fontScale=1,
                    color=(200,0,0), thickness=1, lineType=cv2.LINE_AA)
    
    # 영상출력
    cv2.imshow('frame', frame)
    # 중단여부 확인
    if cv2.waitKey(1) == 27:  # esc 입력하면
        break

# 마무리
cap.release() # 웹캠 연결 종료
cv2.destroyAllWindows() # 출력 윈도우 종료
